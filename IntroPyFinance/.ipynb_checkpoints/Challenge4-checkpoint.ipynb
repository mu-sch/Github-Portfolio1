# %%
# RSI Challenge

# %%
from matplotlib import dates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

raw = yf.download('SPY AAPL', start = '2010-01-01', end = '2019-12-31')
raw

def fix_cols(df):
    columns = df.columns
    outer = [col[0] for col in columns]      # using a list comprehension to extract the first entry for each tuple in 
    df.columns = outer                       # the multi-index from .columns ^above^
    return df                                        

(raw
 .iloc[:, ::2]
 .pipe(fix_cols)
)

def tweak_data():
    raw = yf.download('SPY AAPL', start = '2010-01-01', end = '2019-12-31')
                    
    return(raw
     .iloc[:, :-2:2] # :-2:2 takes out volume, ::2 leaves volume in
     .pipe(fix_cols)
)
                      
tweak_data()


# TO define apple data
aapl = (raw
        .iloc[:,::2]
        .pipe(fix_cols))
aapl
# Out:
# [*********************100%***********************]  2 of 2 completed
# [*********************100%***********************]  2 of 2 completed
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2010-01-04   6.505280   7.643214   7.660714   7.585000   7.622500  493729600
# 2010-01-05   6.516528   7.656429   7.699643   7.616071   7.664286  601904800
# 2010-01-06   6.412874   7.534643   7.686786   7.526786   7.656429  552160000
# 2010-01-07   6.401017   7.520714   7.571429   7.466071   7.562500  477131200
# 2010-01-08   6.443574   7.570714   7.571429   7.466429   7.510714  447610800
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-23  69.451065  71.000000  71.062500  70.092499  70.132500   98572000
# 2019-12-24  69.517082  71.067497  71.222504  70.730003  71.172501   48478800
# 2019-12-26  70.896339  72.477501  72.495003  71.175003  71.205002   93121200
# 2019-12-27  70.869423  72.449997  73.492500  72.029999  72.779999  146266000
# 2019-12-30  71.290047  72.879997  73.172501  71.305000  72.364998  144114400
#
# [2515 rows x 6 columns]

# %%
# %%timeit
(aapl
 .assign(change=lambda df:df['Close'].diff(),
         gain=lambda df:df.change.clip(lower=0)
         loss=lambda df:df.change.clip(upper=0)
         avg_gain=lambda df:avg(df, col='gain'),
         avg_loss=lambda df:avg(df, col='loss'),
         rs=lambda df:df.avg_gain/df.avg_loss,
         # RSI = IF(I17=0,100,100-(100/(1+J17)))
         rsi=lambda df:np.select([df.avg_loss==0], [100],
                                (100-(100/(1+df.rs))))
        )
)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\Michael\AppData\Local\Temp\ipykernel_4860\2808592604.py", line 1, in <module>
#     get_ipython().run_cell_magic('timeit', '', "(aapl\n .assign(change=lambda df:df['Close'].diff(),\n         gain=lambda df:df.change.clip(lower=0)\n         loss=lambda df:df.change.clip(upper=0)\n         avg_gain=lambda df:avg(df, col='gain'),\n         avg_loss=lambda df:avg(df, col='loss'),\n         rs=lambda df:df.avg_gain/df.avg_loss,\n         # RSI = IF(I17=0,100,100-(100/(1+J17)))\n         rsi=lambda df:np.select([df.avg_loss==0], [100],\n                                (100-(100/(1+df.rs))))\n        )\n)\n         \n")
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2419, in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\decorator.py", line 232, in fun
#     return caller(func, *(extras + args), **kw)
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\magics\execution.py", line 1126, in timeit
#     ast_stmt = self.shell.compile.ast_parse(transform(cell))
#
#   File "C:\Users\Michael\anaconda3\lib\site-packages\IPython\core\compilerop.py", line 101, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 4
#     loss=lambda df:df.change.clip(upper=0)
#     ^
# SyntaxError: invalid syntax

# %%
import numba as nb

# %%
# try with big data

big= np.random.rand(10_000_000)
big_df = pd.DataFrame({'val':big})

# %%
# %%timeit
(big_df
 .assign(smooth=lambda df:avg_nb(df.val.to_numpy(), 14))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4860\2755750769.py in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', '(big_df\n .assign(smooth=lambda df:avg_nb(df.val.to_numpy(), 14))\n)\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1178             for index in range(0, 10):
#    1179                 number = 10 ** index
# -> 1180                 time_number = timer.timeit(number)
#    1181                 if time_number >= 0.2:
#    1182                     break
#
# ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in assign(self, **kwargs)
#    4513
#    4514         for k, v in kwargs.items():
# -> 4515             data[k] = com.apply_if_callable(v, data)
#    4516         return data
#    4517
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     356     """
#     357     if callable(maybe_callable):
# --> 358         return maybe_callable(obj, **kwargs)
#     359
#     360     return maybe_callable
#
# <magic-timeit> in <lambda>(df)
#
# NameError: name 'avg_nb' is not defined
